# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus-haruki/projeto_estadios/blob/main/ExemploEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.4 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente = MongoClient("mongodb+srv://harukimatheus:Matheus123@clusterestadios.pdecn.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios")

# %%
db = cliente.get_database('futebol')

# %%
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('6714576e64a4a77c6ce0c015'), ObjectId('6714576e64a4a77c6ce0c016'), ObjectId('6714576e64a4a77c6ce0c017'), ObjectId('6714576e64a4a77c6ce0c018'), ObjectId('6714576e64a4a77c6ce0c019'), ObjectId('6714576e64a4a77c6ce0c01a'), ObjectId('6714576e64a4a77c6ce0c01b'), ObjectId('6714576e64a4a77c6ce0c01c'), ObjectId('6714576e64a4a77c6ce0c01d'), ObjectId('6714576e64a4a77c6ce0c01e'), ObjectId('6714576e64a4a77c6ce0c01f'), ObjectId('6714576e64a4a77c6ce0c020'), ObjectId('6714576e64a4a77c6ce0c021'), ObjectId('6714576e64a4a77c6ce0c022'), ObjectId('6714576e64a4a77c6ce0c023'), ObjectId('6714576e64a4a77c6ce0c024'), ObjectId('6714576e64a4a77c6ce0c025'), ObjectId('6714576e64a4a77c6ce0c026'), ObjectId('6714576e64a4a77c6ce0c027'), ObjectId('6714576e64a4a77c6ce0c028')], acknowledged=True)

# %%
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterestadios-shard-00-02.pdecn.mongodb.net:27017', 'clusterestadios-shard-00-00.pdecn.mongodb.net:27017', 'clusterestadios-shard-00-01.pdecn.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterEstadios', authsource='admin', replicaset='atlas-14esmp-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('67144bdd5a94562a8e6a488f'),
#   'nome': 'Vila Belmiro',
#   'capacidade': '21732',
#   'latitude': '-23.57243',
#   'longitude': '-46.20123'},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c015'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c016'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c017'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c018'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c019'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c01a'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c01b'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c01c'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c01d'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c01e'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c01f'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c020'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c021'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c022'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c023'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c024'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c025'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c026'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c027'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('6714576e64a4a77c6ce0c028'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           67144bdd5a94562a8e6a488f
# nome                      Vila Belmiro
# capacidade                       21732
# latitude                     -23.57243
# longitude                    -46.20123
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[ center_lat , center_lon ], zoom_start=5, width=800, height=600 )

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 21

# %%
for i in range(qtde) :
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  description = 'Estádio: ' + str(df_convertido.iloc[i]['nome'])+ '<br> Capacidade: ' +  str(df_convertido.iloc[i]['capacidade'])
  folium.Marker([ lat, lng ],
                popup= description,
                icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66194afa97c169e53361845f6c81f97e {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66194afa97c169e53361845f6c81f97e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66194afa97c169e53361845f6c81f97e = L.map(
#                 &quot;map_66194afa97c169e53361845f6c81f97e&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f18551f0b8484a346ea482b797d2d256 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f18551f0b8484a346ea482b797d2d256.addTo(map_66194afa97c169e53361845f6c81f97e);
#
#
#             var marker_eae27ed0438c2c2dec2bb05bfe5f13ec = L.marker(
#                 [-23.57243, -46.20123],
#                 {}
#             ).addTo(map_66194afa97c169e53361845f6c81f97e);
#
#
#             var icon_66f337a640a9600a060bd8af1285b48c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eae27ed0438c2c2dec2bb05bfe5f13ec.setIcon(icon_66f337a640a9600a060bd8af1285b48c);
#
#
#         var popup_3fe819ce73c8a7aa26b9be575db8416a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b06f703c624ce7603b5e4de83b993ab4 = $(`&lt;div id=&quot;html_b06f703c624ce7603b5e4de83b993ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Vila Belmiro&lt;br&gt; Capacidade: 21732&lt;/div&gt;`)[0];
#                 popup_3fe819ce73c8a7aa26b9be575db8416a.setContent(html_b06f703c624ce7603b5e4de83b993ab4);
#
#
#
#         marker_eae27ed0438c2c2dec2bb05bfe5f13ec.bindPopup(popup_3fe819ce73c8a7aa26b9be575db8416a)
#         ;
#
#
#
#
#             var marker_0eef87ea9c535613bc722917021592f3 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_66194afa97c169e53361845f6c81f97e);
#
#
#             var icon_2933fb3e127e3c1e994215d5d16aee22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0eef87ea9c535613bc722917021592f3.setIcon(icon_2933fb3e127e3c1e994215d5d16aee22);
#
#
#         var popup_6635152c57dec6e5bd2b2761f44f28f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52e6768ac96969853fae0a9f67f7d8e7 = $(`&lt;div id=&quot;html_52e6768ac96969853fae0a9f67f7d8e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_6635152c57dec6e5bd2b2761f44f28f5.setContent(html_52e6768ac96969853fae0a9f67f7d8e7);
#
#
#
#         marker_0eef87ea9c535613bc722917021592f3.bindPopup(popup_6635152c57dec6e5bd2b2761f44f28f5)
#         ;
#
#
#
#
#             var marker_04a89c2025b3bf107e4e26b710009108 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_66194afa97c169e53361845f6c81f97e);
#
#
#             var icon_3e6baf80b8da1a4e8cf9a65c0298b47d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_04a89c2025b3bf107e4e26b710009108.setIcon(icon_3e6baf80b8da1a4e8cf9a65c0298b47d);
#
#
#         var popup_441607d00a4e876d1adc53bc8b17ae27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21b54a90925750ff3f98547f185e3756 = $(`&lt;div id=&quot;html_21b54a90925750ff3f98547f185e3756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_441607d00a4e876d1adc53bc8b17ae27.setContent(html_21b54a90925750ff3f98547f185e3756);
#
#
#
#         marker_04a89c2025b3bf107e4e26b710009108.bindPopup(popup_441607d00a4e876d1adc53bc8b17ae27)
#         ;
#
#
#
#
#             var marker_171b903c764697d8f267811e6a75c84d = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_66194afa97c169e53361845f6c81f97e);
#
#
#             var icon_fb123ebca2d0d22df836346c1b337f68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-
